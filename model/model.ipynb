# %%
import pandas as pd

# %%
# Person ID: An identifier for each individual.
# Gender: The gender of the person (Male/Female).
# Age: The age of the person in years.
# Occupation: The occupation or profession of the person.
# Sleep Duration (hours): The number of hours the person sleeps per day.
# Quality of Sleep (scale: 1-10): A subjective rating of the quality of sleep, ranging from 1 to 10.
# Physical Activity Level (minutes/day): The number of minutes the person engages in physical activity daily.
# Stress Level (scale: 1-10): A subjective rating of the stress level experienced by the person, ranging from 1 to 10.
# BMI Category: The BMI category of the person (e.g., Underweight, Normal, Overweight).
# Blood Pressure (systolic/diastolic): The blood pressure measurement of the person, indicated as systolic pressure over diastolic pressure.
# Heart Rate (bpm): The resting heart rate of the person in beats per minute.
# Daily Steps: The number of steps the person takes per day.
# Sleep Disorder: The presence or absence of a sleep disorder in the person (Healthy, Insomnia, Sleep Apnea).

# Details about Sleep Disorder Column:

# None: The individual does not exhibit any specific sleep disorder.
# Insomnia: The individual experiences difficulty falling asleep or staying asleep, leading to inadequate or poor-quality sleep.
# Sleep Apnea: The individual suffers from pauses in breathing during sleep, resulting in disrupted sleep patterns and potential health risks.

# %%
df = pd.read_csv('Sleep_Data_Sampled.csv')

# %%
df
# Out:
#        Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0              1    Male   35             Doctor            6.65
# 1              2    Male   42            Teacher            6.90
# 2              3    Male   34  Software Engineer            6.95
# 3              4    Male   32             Doctor            6.90
# 4              5    Male   37             Lawyer            6.85
# ...          ...     ...  ...                ...             ...
# 14995      14996  Female   59              Nurse            8.10
# 14996      14997  Female   59              Nurse            8.00
# 14997      14998  Female   59              Nurse            8.10
# 14998      14999  Female   59              Nurse            8.10
# 14999      15000  Female   59              Nurse            8.10
#
#        Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0                     7                       50             7  Normal Weight
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                15000 non-null  int64
#  1   Gender                   15000 non-null  object
#  2   Age                      15000 non-null  int64
#  3   Occupation               15000 non-null  object
#  4   Sleep Duration           15000 non-null  float64
#  5   Quality of Sleep         15000 non-null  int64
#  6   Physical Activity Level  15000 non-null  int64
#  7   Stress Level             15000 non-null  int64
#  8   BMI Category             15000 non-null  object
#  9   Blood Pressure           15000 non-null  object
#  10  Heart Rate               15000 non-null  int64
#  11  Daily Steps              15000 non-null  int64
#  12  Sleep Disorder           15000 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.5+ MB

# %%
df['Sleep Disorder'].unique()
# Out:
# array(['Healthy', 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
import seaborn as sns

# %%
# None: The individual does not exhibit any specific sleep disorder so normal sleep

# %%
# df[df['Sleep Disorder'].isnull()].shape

# %%
# df.loc[df['Sleep Disorder'].isnull(), 'Sleep Disorder'] = 'Normal Sleep'

# %%
sns.countplot(x='Sleep Disorder', data=df)
# Out:
# <Axes: xlabel='Sleep Disorder', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
df['Person ID']
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 14995    14996
# 14996    14997
# 14997    14998
# 14998    14999
# 14999    15000
# Name: Person ID, Length: 15000, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([35, 42, 34, 32, 37, 33, 44, 40, 36, 46, 38, 48, 30, 31, 41, 45, 39,
#        50, 54, 43, 47, 56, 49, 28, 55, 52, 53, 51, 29, 58, 59, 57, 27],
#       dtype=int64)

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,15)

# %%
sns.countplot(x = 'Age', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df['Occupation'].unique()
# Out:
# array(['Doctor', 'Teacher', 'Software Engineer', 'Lawyer', 'Engineer',
#        'Accountant', 'Nurse', 'Scientist', 'Manager', 'Salesperson',
#        'Sales Representative'], dtype=object)

# %%
sns.countplot(x = 'Occupation', data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                15000 non-null  int64
#  1   Gender                   15000 non-null  object
#  2   Age                      15000 non-null  int64
#  3   Occupation               15000 non-null  object
#  4   Sleep Duration           15000 non-null  float64
#  5   Quality of Sleep         15000 non-null  int64
#  6   Physical Activity Level  15000 non-null  int64
#  7   Stress Level             15000 non-null  int64
#  8   BMI Category             15000 non-null  object
#  9   Blood Pressure           15000 non-null  object
#  10  Heart Rate               15000 non-null  int64
#  11  Daily Steps              15000 non-null  int64
#  12  Sleep Disorder           15000 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.5+ MB

# %%
df['Sleep Duration'].unique()
# Out:
# array([6.65, 6.9 , 6.95, 6.85, 7.85, 8.05, 7.15, 7.8 , 6.6 , 7.1 , 7.5 ,
#        7.55, 7.  , 8.  , 7.45, 7.35, 7.75, 7.6 , 6.8 , 7.25, 7.7 , 6.55,
#        7.3 , 8.1 , 7.2 , 6.1 , 8.15, 8.2 , 7.4 , 6.75, 8.3 , 6.3 , 6.  ,
#        8.4 , 7.65, 8.25, 7.05, 6.7 , 7.95, 6.2 , 6.15, 8.35, 6.05, 7.9 ,
#        8.45, 6.45, 6.25, 6.4 , 6.35, 8.5 , 6.5 , 5.95, 5.9 , 5.85, 5.8 ])

# %%
sns.distplot(df['Sleep Duration'])
df['Sleep Duration'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_12124\3531234386.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sleep Duration'])
# 0.34663669244349105

# %%
df['Quality of Sleep'].unique()
# Out:
# array([7, 8, 6, 9, 5, 4], dtype=int64)

# %%
sns.countplot(x = 'Quality of Sleep', data=df)
# Out:
# <Axes: xlabel='Quality of Sleep', ylabel='count'>

# %%
df['Physical Activity Level'].unique()
# Out:
# array([50, 52, 66, 60, 45, 58, 68, 75, 82, 72, 51, 30, 38, 55, 36, 90, 62,
#        54, 35, 40, 65, 42, 78, 70, 85, 48, 61, 80, 44, 41, 46, 47, 56, 88,
#        31, 34, 32], dtype=int64)

# %%
sns.distplot(df['Physical Activity Level'])
df['Physical Activity Level'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_12124\539533878.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Physical Activity Level'])
# 0.20493535985570616

# %%
df['Stress Level'].unique()
# Out:
# array([7, 4, 6, 5, 3, 8], dtype=int64)

# %%
sns.countplot(x = 'Stress Level', data= df )
# Out:
# <Axes: xlabel='Stress Level', ylabel='count'>

# %%
df['BMI Category'].unique()
# Out:
# array(['Normal Weight', 'Normal', 'Overweight', 'Obese'], dtype=object)

# %%
sns.countplot(x='BMI Category', data=df)
# Out:
# <Axes: xlabel='BMI Category', ylabel='count'>

# %%
df['Blood Pressure'].unique()
# Out:
# array(['120/80', '135/90', '126/83', '125/80', '130/85', '140/95',
#        '115/75', '122/80', '118/76', '128/85', '128/84', '119/77',
#        '125/82', '118/75', '115/78', '121/79', '117/76', '140/90',
#        '135/88', '129/84', '130/86', '139/91', '132/87', '131/86',
#        '142/92'], dtype=object)

# %%
sns.countplot(x = 'Blood Pressure', data=df)
# Out:
# <Axes: xlabel='Blood Pressure', ylabel='count'>

# %%
df['Heart Rate'].unique()
# Out:
# array([71, 66, 74, 69, 65, 68, 70, 72, 73, 75, 67, 76, 77, 78, 80, 86, 82,
#        85, 84, 83, 81, 79], dtype=int64)

# %%
sns.distplot(df['Heart Rate'])
df['Heart Rate'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_12124\2049842205.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Heart Rate'])
# 0.7350755364471638

# %%
df['Daily Steps'].unique()
# Out:
# array([ 7100,  7000,  6100,  6500,  7500,  5000,  6000,  8000,  9000,
#         5900,  6900,  8500,  4600,  6750,  7400,  5300,  5250,  7650,
#         6150,  5500,  5750,  7750,  6300,  6250, 10000,  7250,  7150,
#         7300,  6800,  6450,  6400,  7050,  5600,  5100,  4900,  6650,
#         4850,  8650,  8400,  6200,  6550,  6600,  4200,  8750,  5200,
#         5350,  5150,  5650,  7600,  5550,  3700,  4500,  6850,  4550,
#         4000,  5850,  4450,  4250,  3500,  6050,  4350,  4150,  4100,
#         3650,  3850,  5050,  4050,  3900,  3550,  3000,  4400,  3150,
#         3300,  3350,  5400,  4750,  3750,  3250,  3800,  4800],
#       dtype=int64)

# %%
sns.distplot(df['Daily Steps'])
df['Daily Steps'].skew()
# Out:
# C:\Users\Promantus\AppData\Local\Temp\ipykernel_12124\4041796171.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Daily Steps'])
# 0.46418696831023265

# %%
sns.countplot(x='Stress Level', hue= 'Sleep Disorder', data=df)
# Out:
# <Axes: xlabel='Stress Level', ylabel='count'>

# %%
sns.countplot(x='Occupation', hue= 'Sleep Disorder', data=df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df['Sleep Disorder'].unique()
# Out:
# array(['Healthy', 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array(['Doctor', 'Teacher', 'Software Engineer', 'Lawyer', 'Engineer',
#        'Accountant', 'Nurse', 'Scientist', 'Manager', 'Salesperson',
#        'Sales Representative'], dtype=object)

# %%
df.loc[df['Occupation']=='Software Engineer', 'Occupation'] = 0
df.loc[df['Occupation']=='Doctor', 'Occupation'] = 1
df.loc[df['Occupation']=='Sales Representative', 'Occupation'] = 2
df.loc[df['Occupation']=='Teacher', 'Occupation'] = 3
df.loc[df['Occupation']=='Nurse', 'Occupation'] = 4
df.loc[df['Occupation']=='Engineer', 'Occupation'] = 5
df.loc[df['Occupation']=='Accountant', 'Occupation'] = 6
df.loc[df['Occupation']=='Scientist', 'Occupation'] = 7
df.loc[df['Occupation']=='Lawyer', 'Occupation'] = 8
df.loc[df['Occupation']=='Salesperson', 'Occupation'] = 9
df.loc[df['Occupation']=='Manager', 'Occupation'] = 10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                15000 non-null  int64
#  1   Gender                   15000 non-null  object
#  2   Age                      15000 non-null  int64
#  3   Occupation               15000 non-null  object
#  4   Sleep Duration           15000 non-null  float64
#  5   Quality of Sleep         15000 non-null  int64
#  6   Physical Activity Level  15000 non-null  int64
#  7   Stress Level             15000 non-null  int64
#  8   BMI Category             15000 non-null  object
#  9   Blood Pressure           15000 non-null  object
#  10  Heart Rate               15000 non-null  int64
#  11  Daily Steps              15000 non-null  int64
#  12  Sleep Disorder           15000 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.5+ MB

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.loc[df['Gender']=='Male', 'Gender'] = 0
df.loc[df['Gender']=='Female', 'Gender'] = 1

# %%
df['Gender'].unique()
# Out:
# array([0, 1], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([1, 3, 0, 8, 5, 6, 4, 7, 10, 9, 2], dtype=object)

# %%
df['BMI Category'].unique()
# Out:
# array(['Normal Weight', 'Normal', 'Overweight', 'Obese'], dtype=object)

# %%
df.loc[df['BMI Category']=='Overweight', 'BMI Category'] = 0
df.loc[df['BMI Category']=='Normal', 'BMI Category'] = 1
df.loc[df['BMI Category']=='Obese', 'BMI Category'] = 2
df.loc[df['BMI Category']=='Normal Weight', 'BMI Category'] = 3

# %%
df['Blood Pressure'].unique()
# Out:
# array(['120/80', '135/90', '126/83', '125/80', '130/85', '140/95',
#        '115/75', '122/80', '118/76', '128/85', '128/84', '119/77',
#        '125/82', '118/75', '115/78', '121/79', '117/76', '140/90',
#        '135/88', '129/84', '130/86', '139/91', '132/87', '131/86',
#        '142/92'], dtype=object)

# %%
df.loc[df['Blood Pressure']=='126/83', 'Blood Pressure'] = 0
df.loc[df['Blood Pressure']=='125/80', 'Blood Pressure'] = 1
df.loc[df['Blood Pressure']=='140/90', 'Blood Pressure'] = 2
df.loc[df['Blood Pressure']=='120/80', 'Blood Pressure'] = 3
df.loc[df['Blood Pressure']=='132/87', 'Blood Pressure'] = 4
df.loc[df['Blood Pressure']=='130/86', 'Blood Pressure'] = 5
df.loc[df['Blood Pressure']=='117/76', 'Blood Pressure'] = 6
df.loc[df['Blood Pressure']=='118/76', 'Blood Pressure'] = 7
df.loc[df['Blood Pressure']=='128/85', 'Blood Pressure'] = 8
df.loc[df['Blood Pressure']=='131/86', 'Blood Pressure'] = 9
df.loc[df['Blood Pressure']=='128/84', 'Blood Pressure'] = 10
df.loc[df['Blood Pressure']=='115/75', 'Blood Pressure'] = 11
df.loc[df['Blood Pressure']=='135/88', 'Blood Pressure'] = 12
df.loc[df['Blood Pressure']=='129/84', 'Blood Pressure'] = 13
df.loc[df['Blood Pressure']=='130/85', 'Blood Pressure'] = 15
df.loc[df['Blood Pressure']=='115/78', 'Blood Pressure'] = 16
df.loc[df['Blood Pressure']=='119/77', 'Blood Pressure'] = 17
df.loc[df['Blood Pressure']=='121/79', 'Blood Pressure'] = 18
df.loc[df['Blood Pressure']=='125/82', 'Blood Pressure'] = 19
df.loc[df['Blood Pressure']=='135/90', 'Blood Pressure'] = 20
df.loc[df['Blood Pressure']=='122/80', 'Blood Pressure'] = 21
df.loc[df['Blood Pressure']=='142/92', 'Blood Pressure'] = 22
df.loc[df['Blood Pressure']=='140/95', 'Blood Pressure'] = 23
df.loc[df['Blood Pressure']=='139/91', 'Blood Pressure'] = 24
df.loc[df['Blood Pressure']=='118/75', 'Blood Pressure'] = 25

# %%
df['Blood Pressure'].unique()
# Out:
# array([3, 20, 0, 1, 15, 23, 11, 21, 7, 8, 10, 17, 19, 25, 16, 18, 6, 2,
#        12, 13, 5, 24, 4, 9, 22], dtype=object)

# %%
df['Sleep Disorder'].unique()
# Out:
# array(['Healthy', 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                15000 non-null  int64
#  1   Gender                   15000 non-null  object
#  2   Age                      15000 non-null  int64
#  3   Occupation               15000 non-null  object
#  4   Sleep Duration           15000 non-null  float64
#  5   Quality of Sleep         15000 non-null  int64
#  6   Physical Activity Level  15000 non-null  int64
#  7   Stress Level             15000 non-null  int64
#  8   BMI Category             15000 non-null  object
#  9   Blood Pressure           15000 non-null  object
#  10  Heart Rate               15000 non-null  int64
#  11  Daily Steps              15000 non-null  int64
#  12  Sleep Disorder           15000 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 1.5+ MB

# %%
x = df[['Gender','Age','Occupation','Sleep Duration','Quality of Sleep','Physical Activity Level','Stress Level','BMI Category','Blood Pressure','Heart Rate','Daily Steps']]

# %%
y = df['Sleep Disorder']

# %%
x
# Out:
#       Gender  Age Occupation  Sleep Duration  Quality of Sleep  \
# 0          0   35          1            6.65                 7
# 1          0   42          3            6.90                 8
# 2          0   34          0            6.95                 7
# 3          0   32          1            6.90                 6
# 4          0   37          8            6.85                 7
# ...      ...  ...        ...             ...               ...
# 14995      1   59          4            8.10                 9
# 14996      1   59          4            8.00                 9
# 14997      1   59          4            8.10                 9
# 14998      1   59          4            8.10                 9
# 14999      1   59          4            8.10                 9
#
#        Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# 0                           50             7            3              3
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
from sklearn.ensemble import GradientBoostingClassifier
rfc = GradientBoostingClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
rfc.score(x_train,y_train)
# Out:
# 0.9628571428571429

# %%
from sklearn.metrics import accuracy_score
y_pref = rfc.predict(x_test)
accuracy_score(y_pref,y_test)
# Out:
# 0.9515555555555556

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_pref,y_test))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.93      0.96      0.95      1438
#     Insomnia       0.95      0.96      0.96      1491
#  Sleep Apnea       0.97      0.94      0.95      1571
#
#     accuracy                           0.95      4500
#    macro avg       0.95      0.95      0.95      4500
# weighted avg       0.95      0.95      0.95      4500

# %%
y_pred = rfc.predict(x_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[1377,   42,   54],
#        [  30, 1428,   40],
#        [  31,   21, 1477]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
import pickle

pickle.dump(rfc,open('sleep_boost.pkl','wb'))
boost = pickle.load(open('sleep_boost.pkl','rb'))

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
Model=QuadraticDiscriminantAnalysis()

# %%
Model.fit(x_train,y_train)
# Out:
# QuadraticDiscriminantAnalysis()

# %%
Model.score(x_train,y_train)
# Out:
# 0.9261904761904762

# %%
from sklearn.metrics import accuracy_score
y_pref = Model.predict(x_test)
accuracy_score(y_test,y_pref)
# Out:
# 0.92

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_pref,y_test))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.95      0.89      0.92      1573
#     Insomnia       0.89      0.94      0.91      1414
#  Sleep Apnea       0.92      0.93      0.93      1513
#
#     accuracy                           0.92      4500
#    macro avg       0.92      0.92      0.92      4500
# weighted avg       0.92      0.92      0.92      4500

# %%
y_pred = Model.predict(x_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[1402,   36,   35],
#        [ 102, 1328,   68],
#        [  69,   50, 1410]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()

# %%
import pickle

pickle.dump(Model,open('sleep_Quadra.pkl','wb'))
Quadra = pickle.load(open('sleep_Quadra.pkl','rb'))
